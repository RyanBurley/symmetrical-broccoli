# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
coordinates = pd.read_csv('catalog.csv')

# %%
coordinates
# Out:
#       id         ra        dec
# 0      0  14.872331  42.196759
# 1      1  13.574176  41.300389
# 2      2  13.235401  42.160339
# 3      3  14.298795  40.872113
# 4      4  14.352350  41.013290
# ..   ...        ...        ...
# 995  995  13.617983  40.745974
# 996  996  15.178808  40.272412
# 997  997  13.874008  41.887622
# 998  998  14.253721  40.329210
# 999  999  14.219876  41.403696
#
# [1000 rows x 3 columns]

# %%
plt.plot(coordinates['ra'],coordinates['dec'],'o',markersize=4,color='green')
plt.xlabel('Right Ascension (deg)')
plt.ylabel('Declination (deg)')
# Out:
# Text(0, 0.5, 'Declination (deg)')

# %%
plt.scatter(coordinates['ra'],coordinates['dec'],s=10)
plt.xlabel('Right Ascension (deg)')
plt.ylabel('Declination (deg)');
